# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split


# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder


# Models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import plot_confusion_matrix

# %%
# Load the dataset
df = pd.read_csv("saudi_projects_v02.csv")

# %%
# Handling missing values
df = df.drop(['Unnamed: 0'],axis=1)
cols = ['region_project']
df[cols] = df[cols].fillna(df.mode().iloc[0])
mean = ['project_area']
df[mean] = df[mean].fillna(df.mean().iloc[0])
df = df.dropna(subset=['budget_project'])
df = df[df['budget_project'] <= 86537642000]

# %%
# Split the dataset 

train, test = train_test_split(
    df,
    test_size=0.2,
    train_size = 0.8,
    random_state=9000
)

# %%
X_train = df.drop(['budget_project','end_month','end_year','enddate_project','start_month', 'start_year','startday_project','duration_project'],axis = 1)
y_train = df['budget_project']

X_test = df.drop(['budget_project','end_month','end_year','enddate_project','start_month', 'start_year','startday_project','duration_project'],axis = 1)
y_test = df['budget_project']

X_train.shape
# Out:
# (835, 6)

# %%
# Define a function to calculate the cost for each model
def reg_cost(method, actual, preds):
    mae = mean_absolute_error(y_true=actual, y_pred=preds)
    mse = mean_squared_error(y_true=actual, y_pred=preds)
    
    print(f'Cost functions for the {method} regression is:')
    print(f'Mean Square Error: {round(mse,2)}')
    print(f'Mean Absolute Error: {round(mae,2)}\n\n')

# %%
#ordinal encoder
ordinal = OrdinalEncoder()

col_names = ["sectors","type_project","region_project","status_project"]

## Ordinal encode the column
ordinal_ls = ordinal.fit_transform(X_train[col_names])
ordinal_ls_val = ordinal.transform(X_test[col_names])

# %%
ordinal.categories_
# Out:
# [array([' Charity', ' Commercial', ' Educational', ' Governmental',
#         ' Health', ' Industrial', ' Residential', ' Scientific', ' Sports',
#         ' Tourist'], dtype=object),
#  array(['Charity', 'Charity, Health', 'Charity, Residential', 'Commercial',
#         'Commercial, Educational',
#         'Commercial, Educational, Charity, Residential, Health',
#         'Commercial, Educational, Governmental, Charity, Residential, Health',
#         'Commercial, Educational, Health',
#         'Commercial, Educational, Residential', 'Commercial, Governmental',
#         'Commercial, Health', 'Commercial, Industrial',
#         'Commercial, Residential', 'Commercial, Tourist',
#         'Commercial, Tourist, Governmental, Sports',
#         'Commercial, Tourist, Residential', 'Educational',
#         'Educational, Charity', 'Educational, Charity, Sports',
#         'Educational, Governmental', 'Educational, Governmental, Health',
#         'Educational, Governmental, Residential', 'Educational, Health',
#         'Educational, Residential', 'Educational, Scientific',
#         'Educational, Sports', 'Governmental', 'Governmental, Charity',
#         'Governmental, Charity, Scientific', 'Governmental, Health',
#         'Governmental, Industrial', 'Governmental, Residential',
#         'Governmental, Residential, Health', 'Governmental, Scientific',
#         'Governmental, Scientific, Health',
#         'Governmental, Scientific, Industrial', 'Governmental, Sports',
#         'Health', 'Hotel, Charity', 'Hotel, Commercial',
#         'Hotel, Commercial, Charity',
#         'Hotel, Commercial, Charity, Residential',
#         'Hotel, Commercial, Governmental, Residential',
#         'Hotel, Commercial, Residential', 'Hotel, Commercial, Tourist',
#         'Hotel, Commercial, Tourist, Residential', 'Hotel, Governmental',
#         'Hotel, Health',
#         'Hotel, Infrastructure, Commercial, Educational, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Residential',
#         'Hotel, Infrastructure, Commercial, Tourist, Educational, Charity, Sports, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Tourist, Educational, Governmental, Charity, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Tourist, Governmental',
#         'Hotel, Infrastructure, Commercial, Tourist, Residential',
#         'Hotel, Infrastructure, Commercial, Tourist, Sports, Residential',
#         'Hotel, Infrastructure, Tourist, Educational, Governmental, Health',
#         'Hotel, Residential', 'Hotel, Tourist',
#         'Hotel, Tourist, Governmental', 'Industrial', 'Industrial, Health',
#         'Infrastructure, Charity', 'Infrastructure, Commercial',
#         'Infrastructure, Commercial, Educational, Residential, Health',
#         'Infrastructure, Commercial, Residential',
#         'Infrastructure, Commercial, Tourist',
#         'Infrastructure, Commercial, Tourist, Governmental',
#         'Infrastructure, Commercial, Tourist, Governmental, Residential, Scientific',
#         'Infrastructure, Commercial, Tourist, Residential, Health',
#         'Infrastructure, Educational, Governmental',
#         'Infrastructure, Educational, Governmental, Residential',
#         'Infrastructure, Educational, Health',
#         'Infrastructure, Governmental',
#         'Infrastructure, Governmental, Charity, Health',
#         'Infrastructure, Governmental, Charity, Residential, Health',
#         'Infrastructure, Governmental, Health',
#         'Infrastructure, Governmental, Industrial',
#         'Infrastructure, Governmental, Residential',
#         'Infrastructure, Governmental, Residential, Health',
#         'Infrastructure, Industrial', 'Infrastructure, Residential',
#         'Infrastructure, Scientific', 'Infrastructure, Tourist',
#         'Infrastructure, Tourist, Governmental',
#         'Infrastructure, Tourist, Governmental, Residential',
#         'Residential', 'Scientific', 'Sports', 'Tourist',
#         'Tourist, Educational',
#         'Tourist, Educational, Governmental, Sports',
#         'Tourist, Educational, Sports', 'Tourist, Governmental',
#         'Tourist, Governmental, Scientific',
#         'Tourist, Governmental, Sports'], dtype=object),
#  array(['ABHA', 'AD DIRIYAH', 'AL-JUBAIL', 'ALBAHA', 'ALDAMMAM',
#         'ALDHAHRAN', 'ALGHAZALA', 'ALHASSA', 'ALHENAKIYA', 'ALJAZAN',
#         'ALJAZAN, ALSHAQEEQ', 'ALJUBAIL', 'ALJUMUM', 'ALKAMIL', 'ALKHAFJI',
#         'ALKHARJ', 'ALKHOBAR', 'ALQASEEM, MECCA', 'ALTAIF', 'ALULA',
#         'ARAR',
#         'ARAR, RIYADH, BURAYDAH, HAIL, ALMUJMAA, SDAIR, JAWF, EASTERN PROVINCE',
#         'ARRASS', 'ASEER, KAHMIS MUSHAIT', 'BADR', 'BALJURASHI', 'BRAIDAH',
#         'Dumah Al Jandal', 'EASTERN PROVINCE', 'FEIFAA', 'HAFAR ALBATIN',
#         'HAIL', 'JAZAN', 'JEDDAH', 'JEDDAH, MECCA',
#         'JEDDAH, RIYADH, ALDAMAM, MUHAYIL ASEER, MECCA',
#         'KING ABDULLAH CITY', 'LAYLA', 'MADENAH',
#         'MADENAH, RIYADH, EASTERN PROVINCE', 'MECCA',
#         'MECCA, ALMUZAHMIYA, ALJMUM, ALBARABIR, RIYADH, JEDDAH',
#         'MECCA, KING ABDULLAH CITY, MEDINA, JEDDAH', 'MECCA, TAIF',
#         'MEDINA', 'NAJRAN', 'RABIGH', 'RAS ALKHAIR', 'RIYADH', 'SAKAKA',
#         'SDAIR', 'SHAQRA', 'TABUK', 'TABUK, DHUBA', 'TUBARJAL', 'TURAIF',
#         'UNAYZAH', 'WAAD ALSHAMAL', 'YANBAA'], dtype=object),
#  array(['Announced', 'Canceled', 'Complete', 'Late', 'Stumbled',
#         'Suggested projects', 'Under the construction'], dtype=object)]

# %%
X_train[col_names] = ordinal_ls
X_test[col_names] = ordinal_ls_val

X_train.sample(40)
# Out:
#       sectors  sector_budgets  type_project  project_area  region_project  \
# 2107      4.0    549859453510          75.0  7.500000e+03            44.0
# 1423      0.0    473524096855          40.0  7.000000e+03            40.0
# 2052      4.0    549859453510          29.0  8.627200e+04            33.0
# 1472      8.0    396629702256          14.0  3.500000e+05            33.0
# 1113      3.0   1436611825301          29.0  1.500000e+06             0.0
# 1742      6.0    709916354518          85.0  9.198532e+11            48.0
# 360       1.0   1058790791316          68.0  9.198532e+11            33.0
# 470       1.0   1058790791316          12.0  5.000000e+03            33.0
# 1082      3.0   1436611825301          77.0  1.999999e+06            33.0
# 333       1.0   1058790791316           3.0  9.198532e+11            33.0
# 845       2.0    567443636867          19.0  9.198532e+11             6.0
# 806       2.0    567443636867          23.0  0.000000e+00            33.0
# 1146      3.0   1436611825301          26.0  1.000000e+04            48.0
# 1316      3.0   1436611825301          72.0  1.100000e+04            48.0
# 1172      3.0   1436611825301          72.0  3.305000e+03            48.0
# 103       1.0   1058790791316           3.0  9.198532e+11            16.0
# 1108      3.0   1436611825301          26.0  1.500000e+04            23.0
# 430       1.0   1058790791316          10.0  5.397900e+04            16.0
# 1161      3.0   1436611825301          76.0  9.198532e+11            53.0
# 1107      3.0   1436611825301          29.0  2.500000e+06            48.0
# 1112      3.0   1436611825301          20.0  1.450000e+05             7.0
# 1476      8.0    396629702256          54.0  1.100000e+07            58.0
# 278       1.0   1058790791316           9.0  9.198532e+11            33.0
# 2046      4.0    549859453510          10.0  1.450000e+04            48.0
# 1671      6.0    709916354518          85.0  9.198532e+11            36.0
# 1996      5.0   1091256760152          79.0  9.198532e+11            11.0
# 2149      4.0    549859453510          20.0  1.500000e+05             4.0
# 1363      3.0   1436611825301          72.0  1.030000e+08            33.0
# 222       1.0   1058790791316           3.0  9.198532e+11            16.0
# 887       2.0    567443636867          16.0  9.198532e+11            44.0
# 1729      6.0    709916354518          77.0  4.901633e+06            23.0
# 1449      0.0    473524096855          74.0  6.450000e+04            44.0
# 1199      3.0   1436611825301          26.0  2.200000e+04             4.0
# 2021      5.0   1091256760152          11.0  9.198532e+11             2.0
# 1563      6.0    709916354518          85.0  9.198532e+11            48.0
# 1222      3.0   1436611825301          29.0  1.000000e+06            44.0
# 970       3.0   1436611825301          72.0  6.000000e+03            18.0
# 1336      3.0   1436611825301          92.0  7.272810e+05            33.0
# 784       9.0    672120928423          44.0  1.360000e+05            33.0
# 1330      3.0   1436611825301          26.0  5.777500e+04            31.0
#
#       status_project
# 2107             4.0
# 1423             6.0
# 2052             3.0
# 1472             2.0
# 1113             3.0
# 1742             6.0
# 360              4.0
# 470              2.0
# 1082             3.0
# 333              4.0
# 845              6.0
# 806              4.0
# 1146             2.0
# 1316             6.0
# 1172             3.0
# 103              0.0
# 1108             6.0
# 430              3.0
# 1161             3.0
# 1107             6.0
# 1112             3.0
# 1476             6.0
# 278              3.0
# 2046             3.0
# 1671             2.0
# 1996             2.0
# 2149             3.0
# 1363             6.0
# 222              0.0
# 887              6.0
# 1729             3.0
# 1449             3.0
# 1199             0.0
# 2021             3.0
# 1563             0.0
# 1222             4.0
# 970              2.0
# 1336             2.0
# 784              3.0
# 1330             3.0

# %%
scaler = StandardScaler()

## Fit & transform data.
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
# Linear Regression
reg_lin = LinearRegression()
reg_lin.fit(X_train_sc, y_train)

preds_lin = reg_lin.predict(X_test_sc)
mean_absolute_error(y_true=y_test, y_pred=preds_lin)
# Out:
# 4385687863.461437

# %%
# Decision Tree Regressor
reg_tree = DecisionTreeRegressor(random_state = 0, max_depth= 4, criterion= 'mse')
reg_tree.fit(X_train_sc, y_train)

preds_tree = reg_tree.predict(X_test_sc)

mean_absolute_error(y_true=y_test, y_pred=preds_tree)
# Out:
# 2921435460.3583984

# %%
# Random Forest Regressor
reg_forest = RandomForestRegressor(n_estimators = 10, random_state = 0, criterion = 'mse')
reg_forest.fit(X_train_sc, y_train)

preds_forest = reg_forest.predict(X_test_sc)
mean_absolute_error(y_true=y_test, y_pred=preds_forest)
# Out:
# 991374043.9535304

# %%
# SVR
reg_svr = SVR(kernel = 'linear')
reg_svr.fit(X_train_sc, y_train)
# Out:
# SVR(kernel='linear')

# %%
preds_svr = reg_svr.predict(X_test_sc)
mean_absolute_error(y_true=y_test, y_pred=preds_svr)
# Out:
# 3085830004.047136

# %%
# XGB regressor
xgb_reg = xgb.XGBRegressor(objective = "reg:linear",
                           n_estimators = 75,
                           subsample = 0.75,
                           max_depth = 7)
xgb_reg.fit(X_train_sc, y_train)

preds_xgb = xgb_reg.predict(X_test_sc)
mean_absolute_error(y_true=y_test, y_pred=preds_xgb)
# Out:
# [10:34:45] WARNING: d:\bld\xgboost-split_1637426510059\work\src\objective\regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# 212824308.35

# %%
# Cost Function for all the models
model_name = ['linear', 'Decision Tree', 'Random Forest', 'Support Vector', 'XGB regressor']
model_pred = [preds_lin, preds_tree, preds_forest, preds_svr,preds_xgb]

for x in range(len(model_pred)):
    
    reg_cost(model_name[x],y_test, model_pred[x] )
# Out:
# Cost functions for the linear regression is:
# Mean Square Error: 7.757141647892858e+19
# Mean Absolute Error: 4385687863.46
#
#
# Cost functions for the Decision Tree regression is:
# Mean Square Error: 4.435618145589347e+19
# Mean Absolute Error: 2921435460.36
#
#
# Cost functions for the Random Forest regression is:
# Mean Square Error: 7.131113902566983e+18
# Mean Absolute Error: 991374043.95
#
#
# Cost functions for the Support Vector regression is:
# Mean Square Error: 8.776748878653682e+19
# Mean Absolute Error: 3085830004.05
#
#
# Cost functions for the XGB regressor regression is:
# Mean Square Error: 4.23246251058303e+17
# Mean Absolute Error: 212824308.35

# %%
# Save the model
import pickle
filename = 'saudi_projects_regression.pkl'
pickle.dump(xgb_reg, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test_sc, y_test)
print(result)
# Out:
# 0.994687824252392
